# %%
using Images
using TestImages

# %%
img = testimage("lena_gray")
# Out:
# 256×256 Array{Gray{N0f8},2}:
#  Gray{N0f8}(0.635)  Gray{N0f8}(0.635)  …  Gray{N0f8}(0.608)
#  Gray{N0f8}(0.635)  Gray{N0f8}(0.635)     Gray{N0f8}(0.608)
#  Gray{N0f8}(0.635)  Gray{N0f8}(0.635)     Gray{N0f8}(0.608)
#  Gray{N0f8}(0.627)  Gray{N0f8}(0.639)     Gray{N0f8}(0.251)
#  Gray{N0f8}(0.608)  Gray{N0f8}(0.62)      Gray{N0f8}(0.184)
#  Gray{N0f8}(0.612)  Gray{N0f8}(0.612)  …  Gray{N0f8}(0.2)
#  Gray{N0f8}(0.62)   Gray{N0f8}(0.616)     Gray{N0f8}(0.188)
#  Gray{N0f8}(0.62)   Gray{N0f8}(0.624)     Gray{N0f8}(0.192)
#  Gray{N0f8}(0.612)  Gray{N0f8}(0.608)     Gray{N0f8}(0.192)
#  Gray{N0f8}(0.616)  Gray{N0f8}(0.624)     Gray{N0f8}(0.18)
#  Gray{N0f8}(0.612)  Gray{N0f8}(0.608)  …  Gray{N0f8}(0.18)
#  Gray{N0f8}(0.624)  Gray{N0f8}(0.608)     Gray{N0f8}(0.204)
#  Gray{N0f8}(0.612)  Gray{N0f8}(0.616)     Gray{N0f8}(0.212)
#  ⋮                                     ⋱  ⋮
#  Gray{N0f8}(0.216)  Gray{N0f8}(0.302)     Gray{N0f8}(0.227)
# ...

# %% [markdown]
# ### How to make a box

# %%
c = img[100+1:150-1,100+1:150-1]
# Out:
# 49×49 Array{Gray{N0f8},2}:
#  Gray{N0f8}(0.302)  Gray{N0f8}(0.322)  …  Gray{N0f8}(0.702)
#  Gray{N0f8}(0.302)  Gray{N0f8}(0.329)     Gray{N0f8}(0.71)
#  Gray{N0f8}(0.298)  Gray{N0f8}(0.235)     Gray{N0f8}(0.714)
#  Gray{N0f8}(0.247)  Gray{N0f8}(0.275)     Gray{N0f8}(0.698)
#  Gray{N0f8}(0.325)  Gray{N0f8}(0.353)     Gray{N0f8}(0.718)
#  Gray{N0f8}(0.302)  Gray{N0f8}(0.412)  …  Gray{N0f8}(0.678)
#  Gray{N0f8}(0.259)  Gray{N0f8}(0.357)     Gray{N0f8}(0.686)
#  Gray{N0f8}(0.239)  Gray{N0f8}(0.392)     Gray{N0f8}(0.702)
#  Gray{N0f8}(0.208)  Gray{N0f8}(0.286)     Gray{N0f8}(0.678)
#  Gray{N0f8}(0.2)    Gray{N0f8}(0.286)     Gray{N0f8}(0.675)
#  Gray{N0f8}(0.18)   Gray{N0f8}(0.2)    …  Gray{N0f8}(0.655)
#  Gray{N0f8}(0.188)  Gray{N0f8}(0.192)     Gray{N0f8}(0.604)
#  Gray{N0f8}(0.192)  Gray{N0f8}(0.184)     Gray{N0f8}(0.643)
#  ⋮                                     ⋱
#  Gray{N0f8}(0.165)  Gray{N0f8}(0.153)     Gray{N0f8}(0.498)
# ...

# %%
img[100:150,100:150] = 0
# Out:
# 0

# %%
img
# Out:
# 256×256 Array{Gray{N0f8},2}:
#  Gray{N0f8}(0.635)  Gray{N0f8}(0.635)  …  Gray{N0f8}(0.608)
#  Gray{N0f8}(0.635)  Gray{N0f8}(0.635)     Gray{N0f8}(0.608)
#  Gray{N0f8}(0.635)  Gray{N0f8}(0.635)     Gray{N0f8}(0.608)
#  Gray{N0f8}(0.627)  Gray{N0f8}(0.639)     Gray{N0f8}(0.251)
#  Gray{N0f8}(0.608)  Gray{N0f8}(0.62)      Gray{N0f8}(0.184)
#  Gray{N0f8}(0.612)  Gray{N0f8}(0.612)  …  Gray{N0f8}(0.2)
#  Gray{N0f8}(0.62)   Gray{N0f8}(0.616)     Gray{N0f8}(0.188)
#  Gray{N0f8}(0.62)   Gray{N0f8}(0.624)     Gray{N0f8}(0.192)
#  Gray{N0f8}(0.612)  Gray{N0f8}(0.608)     Gray{N0f8}(0.192)
#  Gray{N0f8}(0.616)  Gray{N0f8}(0.624)     Gray{N0f8}(0.18)
#  Gray{N0f8}(0.612)  Gray{N0f8}(0.608)  …  Gray{N0f8}(0.18)
#  Gray{N0f8}(0.624)  Gray{N0f8}(0.608)     Gray{N0f8}(0.204)
#  Gray{N0f8}(0.612)  Gray{N0f8}(0.616)     Gray{N0f8}(0.212)
#  ⋮                                     ⋱  ⋮
#  Gray{N0f8}(0.216)  Gray{N0f8}(0.302)     Gray{N0f8}(0.227)
# ...

# %%
img[100+1:15+1,100+1:150+1] = 0
img[100+1:150-1,100+1:150-1] = c
# Out:
# 49×49 Array{Gray{N0f8},2}:
#  Gray{N0f8}(0.302)  Gray{N0f8}(0.322)  …  Gray{N0f8}(0.702)
#  Gray{N0f8}(0.302)  Gray{N0f8}(0.329)     Gray{N0f8}(0.71)
#  Gray{N0f8}(0.298)  Gray{N0f8}(0.235)     Gray{N0f8}(0.714)
#  Gray{N0f8}(0.247)  Gray{N0f8}(0.275)     Gray{N0f8}(0.698)
#  Gray{N0f8}(0.325)  Gray{N0f8}(0.353)     Gray{N0f8}(0.718)
#  Gray{N0f8}(0.302)  Gray{N0f8}(0.412)  …  Gray{N0f8}(0.678)
#  Gray{N0f8}(0.259)  Gray{N0f8}(0.357)     Gray{N0f8}(0.686)
#  Gray{N0f8}(0.239)  Gray{N0f8}(0.392)     Gray{N0f8}(0.702)
#  Gray{N0f8}(0.208)  Gray{N0f8}(0.286)     Gray{N0f8}(0.678)
#  Gray{N0f8}(0.2)    Gray{N0f8}(0.286)     Gray{N0f8}(0.675)
#  Gray{N0f8}(0.18)   Gray{N0f8}(0.2)    …  Gray{N0f8}(0.655)
#  Gray{N0f8}(0.188)  Gray{N0f8}(0.192)     Gray{N0f8}(0.604)
#  Gray{N0f8}(0.192)  Gray{N0f8}(0.184)     Gray{N0f8}(0.643)
#  ⋮                                     ⋱
#  Gray{N0f8}(0.165)  Gray{N0f8}(0.153)     Gray{N0f8}(0.498)
# ...

# %%
img
# Out:
# 256×256 Array{Gray{N0f8},2}:
#  Gray{N0f8}(0.635)  Gray{N0f8}(0.635)  …  Gray{N0f8}(0.608)
#  Gray{N0f8}(0.635)  Gray{N0f8}(0.635)     Gray{N0f8}(0.608)
#  Gray{N0f8}(0.635)  Gray{N0f8}(0.635)     Gray{N0f8}(0.608)
#  Gray{N0f8}(0.627)  Gray{N0f8}(0.639)     Gray{N0f8}(0.251)
#  Gray{N0f8}(0.608)  Gray{N0f8}(0.62)      Gray{N0f8}(0.184)
#  Gray{N0f8}(0.612)  Gray{N0f8}(0.612)  …  Gray{N0f8}(0.2)
#  Gray{N0f8}(0.62)   Gray{N0f8}(0.616)     Gray{N0f8}(0.188)
#  Gray{N0f8}(0.62)   Gray{N0f8}(0.624)     Gray{N0f8}(0.192)
#  Gray{N0f8}(0.612)  Gray{N0f8}(0.608)     Gray{N0f8}(0.192)
#  Gray{N0f8}(0.616)  Gray{N0f8}(0.624)     Gray{N0f8}(0.18)
#  Gray{N0f8}(0.612)  Gray{N0f8}(0.608)  …  Gray{N0f8}(0.18)
#  Gray{N0f8}(0.624)  Gray{N0f8}(0.608)     Gray{N0f8}(0.204)
#  Gray{N0f8}(0.612)  Gray{N0f8}(0.616)     Gray{N0f8}(0.212)
#  ⋮                                     ⋱  ⋮
#  Gray{N0f8}(0.216)  Gray{N0f8}(0.302)     Gray{N0f8}(0.227)
# ...

# %%
?c
# Out:
# search: cp cd csc cov cot cos cor cmp cld cis cat csch cscd coth cotd cosh cosd
# No documentation found.
#
# `c` is of type `Array{ColorTypes.Gray{FixedPointNumbers.Normed{UInt8,8}},2}`.
#
# **Summary:**
#
# ```
# mutable struct Array{ColorTypes.Gray{FixedPointNumbers.Normed{UInt8,8}},2} <: DenseArray{ColorTypes.Gray{FixedPointNumbers.Normed{UInt8,8}},2}
# ```
