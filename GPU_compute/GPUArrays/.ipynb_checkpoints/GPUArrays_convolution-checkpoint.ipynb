# %%
using Images, TestImages, PyPlot, BenchmarkTools

# %%
using GPUArrays
using CLArrays

# %%
devices = CLArrays.devices()
# Out:
# 2-element Array{OpenCL.cl.Device,1}:
#  OpenCL.Device(AMD Radeon Pro 580 Compute Engine on Apple @0x0000000001021c00)
#  OpenCL.Device(Intel(R) Core(TM) i7-7700K CPU @ 4.20GHz on Apple @0x00000000ffffffff)

# %%
img = testimage("lena_gray");
img1 = Gray.(img);

# %% [markdown]
# ### CPU convolution

# %%
K = [[1,1,1]  [0,0,0]  [-1,-1,-1]]
X = Float32.(img1);

# %%
function convolution_2d_4(X,K)
    im_width, im_height = size(X)
    @assert im_width == im_height
    array_type = eltype(X)
    f = size(K, 1)
    output = zeros(eltype(X), im_width-f, im_height-f)
    @inbounds  for w in 1:im_width-f
        for h in 1:im_height-f
            aux = 0.
            l = 1
            for col in h:h+f-1
                for row in w:w+f-1
                    aux += X[row,col]*K[l]
                    l +=1
                end
            end
            output[w,h] = aux
        end
    end
    return output
end
# Out:
# convolution_2d_4 (generic function with 1 method)

# %%
@benchmark convolution_2d_4(X,K)
# Out:
# BenchmarkTools.Trial:
#   memory estimate:  250.14 KiB
#   allocs estimate:  2
#   --------------
#   minimum time:     555.770 μs (0.00% GC)
#   median time:      637.680 μs (0.00% GC)
#   mean time:        655.848 μs (3.09% GC)
#   maximum time:     3.084 ms (76.56% GC)
#   --------------
#   samples:          7591
#   evals/sample:     1

# %%
Xconv = convolution_2d_4(X,K)
PyPlot.imshow(Xconv, cmap="gray")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x127fcd3d0>)
# PyObject <matplotlib.image.AxesImage object at 0x12e5a80d0>

# %% [markdown]
# ### GPU convolution

# %%
devices[1]
# Out:
# OpenCL.Device(AMD Radeon Pro 580 Compute Engine on Apple @0x0000000001021c00)

# %%
CLArrays.init(devices[1])
# Out:
# OpenCL context with:
# CL version: OpenCL 1.2
# Device: CL AMD Radeon Pro 580 Compute Engine
#             threads: 256
#              blocks: (256, 256, 256)
#       global_memory: 8589.934592 mb
#  free_global_memory: NaN mb
#        local_memory: 0.032768 mb

# %%
X_gpu = CLArray(X)
# Out:
# GPU: 256×256 Array{Float32,2}:
#  0.635294  0.635294  0.635294  0.639216  …  0.658824  0.670588  0.607843
#  0.635294  0.635294  0.635294  0.639216     0.658824  0.670588  0.607843
#  0.635294  0.635294  0.635294  0.639216     0.658824  0.670588  0.607843
#  0.627451  0.639216  0.627451  0.623529     0.478431  0.360784  0.25098
#  0.607843  0.619608  0.623529  0.615686     0.25098   0.196078  0.184314
#  0.611765  0.611765  0.611765  0.607843  …  0.196078  0.184314  0.2
#  0.619608  0.615686  0.615686  0.623529     0.180392  0.188235  0.188235
#  0.619608  0.623529  0.607843  0.619608     0.192157  0.211765  0.192157
#  0.611765  0.607843  0.619608  0.615686     0.192157  0.176471  0.192157
#  0.615686  0.623529  0.619608  0.603922     0.196078  0.188235  0.180392
#  0.611765  0.607843  0.607843  0.611765  …  0.184314  0.180392  0.180392
#  0.623529  0.607843  0.6       0.611765     0.188235  0.192157  0.203922
#  0.611765  0.615686  0.596078  0.623529     0.192157  0.215686  0.211765
#  ⋮                                       ⋱                      ⋮
#  0.215686  0.301961  0.368627  0.439216     0.270588  0.278431  0.227451
#  0.168627  0.239216  0.313726  0.372549  …  0.25098   0.25098   0.235294
#  0.172549  0.211765  0.247059  0.309804     0.25098   0.223529  0.192157
#  0.2       0.196078  0.243137  0.266667     0.239216  0.207843  0.196078
#  0.196078  0.227451  0.211765  0.254902     0.227451  0.219608  0.231373
#  0.196078  0.262745  0.247059  0.25098      0.196078  0.2       0.180392
#  0.203922  0.219608  0.227451  0.203922  …  0.219608  0.196078  0.207843
#  0.188235  0.219608  0.239216  0.196078     0.223529  0.215686  0.27451
#  0.188235  0.207843  0.207843  0.2          0.239216  0.27451   0.305882
#  0.188235  0.223529  0.211765  0.196078     0.294118  0.380392  0.345098
#  0.180392  0.196078  0.203922  0.196078     0.34902   0.392157  0.384314
#  0.172549  0.215686  0.211765  0.196078  …  0.380392  0.392157  0.411765

# %% [markdown]
# ### Make a GPUcall
#
# ```
# gpu_call(kernel::Function, A::GPUArray, args::Tuple, configuration = length(A))
# ```

# %%
using Transpiler: kernel_source
import Transpiler: cli
using OpenCL

# %%
function test(a::T, b) where {T}
    x = sqrt(sin(a) * b) / T(10.0)
    y = T(33.0)x + cos(b)
    y * T(10.0)
end

function mapkernel(f, a, b, c)
    gid = cli.get_global_id(0) + 1
    c[gid] = f(a[gid], b[gid])
    return
end

# types of mapkernel arguments
T = cli.GlobalPointer{Float32}
argtypes = (typeof(test), T, T, T)
src, method, fname = kernel_source(mapkernel, argtypes)

println(src)
# Out:
# // Inbuilds
# typedef char JLBool;
# // dependencies
# // #mapkernel
# __constant int FUNC_INST_x4mapkernel = 0;
# typedef int x4mapkernel; // empty type emitted as an int
# // #test
# __constant int FUNC_INST_x4test = 0;
# typedef int x4test; // empty type emitted as an int
# // Type{Float32}
# typedef int Type5Float326; // placeholder type instance
# __constant Type5Float326 TYP_INST_Type5Float326 = 0;
#
# // (test, Tuple{Float32,Float32})
# float test_6(float a, float b)
# {
#     ;
#     float y;
#     float x;
#     x = sqrt(sin(a) * b) / (float)(10.0);
#     y = (float)(33.0) * x + cos(b);
#     return y * (float)(10.0);
#     ;
# }
# // ########################
# // Main inner function
# // (mapkernel, (#test, Transpiler.CLIntrinsics.GlobalPointer{Float32}, Transpiler.CLIntrinsics.GlobalPointer{Float32}, Transpiler.CLIntrinsics.GlobalPointer{Float32}))
# __kernel void mapkernel_7(x4test f, __global float *  a, __global float *  b, __global float *  c)
# {
#     ;
#     long gid;
#     gid = get_global_id(0) + 1;
#     float _ssavalue_0;
#     _ssavalue_0 = test_6((a)[gid - 1], (b)[gid - 1]);
#     (c)[gid - 1] = _ssavalue_0;
#     return;
#     ;
# }

# %%
# setup OpenCL buffers, queue and context
a = rand(Float32, 50_000)
b = rand(Float32, 50_000)
device, ctx, queue = cl.create_compute_context()
a_buff = cl.Buffer(Float32, ctx, (:r, :copy), hostbuf=a)
b_buff = cl.Buffer(Float32, ctx, (:r, :copy), hostbuf=b)
c_buff = cl.Buffer(Float32, ctx, :w, length(a))

# compile kernel
p = cl.Program(ctx, source=src) |> cl.build!
k = cl.Kernel(p, fname)
# Out:
# OpenCL Error: | OpenCL Build Warning : Compiler build log:
# <program source>:17:7: warning: no previous prototype for function 'test_6'
# float test_6(float a, float b)
#       ^
#
#  |
# OpenCL.Kernel("mapkernel_7" nargs=4)

# %%
queue(k, size(a), nothing, test, a_buff, b_buff, c_buff)

r = cl.read(queue, c_buff)
# Out:
# 50000-element Array{Float32,1}:
#  32.2196
#  15.3678
#  11.7661
#  19.116
#  10.6962
#  13.6169
#  21.6201
#  26.6874
#  16.4756
#  27.0456
#  17.1718
#  26.2783
#  27.895
#   ⋮
#  24.3836
#  11.838
#  27.5235
#  33.6369
#  10.9794
#  23.5719
#  26.3045
#  24.6101
#  31.6205
#  30.3384
#  30.5244
#  12.8959

# %%
if r ≈ test.(a, b)
    info("Success!")
else
    error("⁉")
end
# Out:
# INFO: Success!
